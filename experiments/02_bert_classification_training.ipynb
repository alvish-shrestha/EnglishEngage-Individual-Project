# %% [markdown]
# incorrect_text → error_category

# %%
pip install torch transformers datasets accelerate
# Out:
# Requirement already satisfied: torch in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (2.9.1)
# Requirement already satisfied: transformers in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (4.57.3)
# Requirement already satisfied: datasets in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (4.4.1)
# Requirement already satisfied: accelerate in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (1.12.0)
# Requirement already satisfied: filelock in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets) (4.12.0)
# Requirement already satisfied: certifi in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: psutil in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from accelerate) (7.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from requests->transformers) (2.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in /Volumes/SSD/6th Sem/Individual Project/Linguadash/venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import torch

from datasets import Dataset
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from transformers import (
    BertTokenizer,
    BertForSequenceClassification,
    TrainingArguments,
    Trainer
)

# %%
df = pd.read_csv("../data/raw/english_language_learning_1M.csv")

df = df[["incorrect_text", "error_category"]].dropna()
df["incorrect_text"] = df["incorrect_text"].str.lower()

le = LabelEncoder()
df["label"] = le.fit_transform(df["error_category"])

# %%
train_df, val_df = train_test_split(
    df,
    test_size=0.2,
    stratify=df["label"],
    random_state=42
)

# %%
train_ds = Dataset.from_pandas(train_df)
val_ds = Dataset.from_pandas(val_df)

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

def tokenize(batch):
    return tokenizer(
        batch["incorrect_text"],
        padding="max_length",
        truncation=True,
        max_length=64
    )

train_ds = train_ds.map(tokenize, batched=True)
val_ds = val_ds.map(tokenize, batched=True)

train_ds = train_ds.rename_column("label", "labels")
val_ds = val_ds.rename_column("label", "labels")

train_ds.set_format("torch", columns=["input_ids", "attention_mask", "labels"])
val_ds.set_format("torch", columns=["input_ids", "attention_mask", "labels"])
# Out:
# Map:   0%|          | 0/800000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200000 [00:00<?, ? examples/s]

# %%
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels=len(le.classes_)
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="./bert_results",
    eval_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    weight_decay=0.01,
    logging_dir="./bert_logs"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds
)

# trainer.train()

# %%
def bert_predict(text):
    model.eval()

    with torch.no_grad():
        inputs = tokenizer(
            text,
            return_tensors="pt",
            truncation=True,
            padding=True
        )

        # MOVE INPUTS TO SAME DEVICE AS MODEL
        inputs = {k: v.to(device) for k, v in inputs.items()}

        outputs = model(**inputs)
        pred_id = torch.argmax(outputs.logits, dim=1).item()

    return le.inverse_transform([pred_id])[0]

# %%
import torch

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)

model.to(device)
# Out:
# Using device: mps
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=5, bias=True)
# )

# %%
bert_predict("He go to school yesterday")
# Out:
# 'punctuation'

# %%
# Save BERT model and tokenizer
model.save_pretrained("./bert_difficulty_model")
tokenizer.save_pretrained("./bert_difficulty_model")
# Out:
# ('./bert_difficulty_model/tokenizer_config.json',
#  './bert_difficulty_model/special_tokens_map.json',
#  './bert_difficulty_model/vocab.txt',
#  './bert_difficulty_model/added_tokens.json')
